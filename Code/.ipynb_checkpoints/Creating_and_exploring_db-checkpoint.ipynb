# %% [markdown]
# # Importing libraries and CSV

# %% [markdown]
# ## Libraries

# %%
# SQL
import pymysql
import sqlalchemy as alch # python -m pip install --upgrade 'sqlalchemy<2.0'

# Get pass for password
from getpass import getpass

# df 
import pandas as pd
import numpy as np 

# Visualization
import plotly.express as px

# %% [markdown]
# ## Importing CSV

# %%
# Check why I have to share all the path 

df = pd.read_csv(r"C:\Users\DavidVicente\Desktop\IronHack\Git_Project_Repos\Project_4_Superstore-Sales-Visualization-\Data\Sample - Superstore.csv", encoding='latin')
df.sample(5)
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 3971    3972  CA-2015-132374   2/22/2015   2/24/2015    Second Class
# 6737    6738  CA-2016-123358   4/10/2016   4/17/2016  Standard Class
# 4857    4858  CA-2015-137526   1/13/2015   1/17/2015  Standard Class
# 2068    2069  CA-2015-133452   4/13/2015   4/19/2015  Standard Class
# 6556    6557  CA-2014-137092  10/20/2014  10/22/2014    Second Class
#
#      Customer ID     Customer Name      Segment        Country  \
# 3971    PS-19045   Penelope Sewall  Home Office  United States
# 6737    BT-11680    Brian Thompson     Consumer  United States
# 4857    PB-19150      Philip Brown     Consumer  United States
# 2068    ZC-21910  Zuschuss Carroll     Consumer  United States
# 6556    LS-16975  Lindsay Shagiari  Home Office  United States
#
#                   City  ... Postal Code   Region       Product ID  \
# 3971  Sterling Heights  ...       48310  Central  OFF-AR-10001615
# 6737     San Francisco  ...       94122     West  OFF-ST-10000636
# 4857       Los Angeles  ...       90004     West  FUR-FU-10001861
# 2068            Pomona  ...       91767     West  TEC-AC-10002800
# 6556           Chicago  ...       60653  Central  OFF-BI-10000632
#
#              Category Sub-Category  \
# 3971  Office Supplies          Art
# 6737  Office Supplies      Storage
# 4857        Furniture  Furnishings
# 2068       Technology  Accessories
# 6556  Office Supplies      Binders
#
#                                            Product Name    Sales  Quantity  \
# 3971                                          Newell 34   79.360         4
# 6737          Rogers Profile Extra Capacity Storage Tub  150.660         9
# 4857  Floodlight Indoor Halogen Bulbs, 1 Bulb per Pa...   77.600         4
# 2068           Plantronics Audio 478 Stereo USB Headset  199.960         4
# 6556                   Satellite Sectional Post Binders    8.682         1
#
#       Discount   Profit
# 3971       0.0  20.6336
# 6737       0.0   6.0264
# 4857       0.0  38.0240
# 2068       0.0  69.9860
# 6556       0.8 -14.7594
#
# [5 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %% [markdown]
# # Dataframe Transformation

# %%
def df_transformation(df):

    # Converting both columns into date data type

    df['Order Date'] = pd.to_datetime(df['Order Date'])
    df['Ship Date'] = pd.to_datetime(df['Ship Date'])

    # Renaming df columns

    df.rename(columns={"Row ID": "Row_ID",
                       "Order ID": "Order_ID", 
                       "Order Date": "Order_Date", 
                       "Ship Date": "Ship_Date", 
                       "Ship Mode": "Ship_Mode",
                       "Customer ID": "Customer_ID",
                       "Customer Name": "Customer_Name",
                       "Postal Code": "Postal_Code", 
                       "Product ID": "Product_ID", 
                       "Product Name": "Product_Name"}, inplace=True)


    # Adding new column with days between order and shipping

    df['Total_Shipping_Days'] = (df['Ship_Date'] - df['Order_Date']).dt.days
    
    # Percentage of profit per sale
    
    df['Profit_Percentage'] = round((df['Profit'] / df['Sales']),2)
    
    # Product Unit price
    
    df['Unit_Price'] = round((df['Sales'] / df['Quantity']),2)

# %%
df_transformation(df)

# %%
df.sample(5)
# Out:
#       Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode  \
# 8667    8668  CA-2016-149916 2016-12-22 2016-12-24    Second Class
# 6180    6181  CA-2015-158421 2015-09-21 2015-09-26  Standard Class
# 4967    4968  CA-2015-122406 2015-08-02 2015-08-05    Second Class
# 4754    4755  CA-2017-126354 2017-02-03 2017-02-08  Standard Class
# 9291    9292  CA-2014-163650 2014-09-23 2014-09-25     First Class
#
#      Customer_ID      Customer_Name      Segment        Country  \
# 8667    ED-13885       Emily Ducich  Home Office  United States
# 6180    GB-14575  Giulietta Baptist     Consumer  United States
# 4967    BE-11455         Brad Eason  Home Office  United States
# 4754    SC-20380   Shahid Collister     Consumer  United States
# 9291    TT-21220    Thomas Thornton     Consumer  United States
#
#                 City  ...         Category  Sub-Category  \
# 8667         Seattle  ...  Office Supplies       Binders
# 6180        Columbia  ...       Technology        Phones
# 4967      Providence  ...  Office Supplies         Paper
# 4754  Pembroke Pines  ...  Office Supplies       Binders
# 9291           Dover  ...  Office Supplies       Binders
#
#                                            Product_Name    Sales Quantity  \
# 8667    Wilson Jones International Size A4 Ring Binders   55.360        4
# 6180                                       HTC One Mini  629.950        5
# 4967  Important Message Pads, 50 4-1/4 x 5-1/2 Forms...    8.400        2
# 4754                             GBC Instant Report Kit    3.882        2
# 9291  Ibico Covers for Plastic or Wire Binding Elements   34.500        3
#
#      Discount   Profit  Total_Shipping_Days  Profit_Percentage  Unit_Price
# 8667      0.2   19.376                    2               0.35       13.84
# 6180      0.0  176.386                    5               0.28      125.99
# 4967      0.0    4.116                    3               0.49        4.20
# 4754      0.7   -2.588                    5              -0.67        1.94
# 9291      0.0   15.525                    2               0.45       11.50
#
# [5 rows x 24 columns]

# %% [markdown]
# # Uploading to db

# %% [markdown]
# - Setting connection to SQL

# %%
password = getpass("Please enter your password: ")

dbName = "superstore"

connectionData=f"mysql+pymysql://root:{password}@localhost/{dbName}"

engine = alch.create_engine(connectionData)
# Out:
# Please enter your password:  ·······

# %%
'''

table = 'superstore_transactions'

df.to_sql(table, if_exists = 'replace', con=engine)

'''
# Out:
# "\n\ntable = 'superstore_transactions'\n\ndf.to_sql(table, if_exists = 'replace', con=engine)\n\n"

# %%
rfm = pd.read_sql_query("""
SELECT * 
    FROM rfm_view;
""", engine)

rfm.head()
# Out:
#   customer_id  rfm_recency  rfm_frequency  rfm_monetary  rfm_combined
# 0    TS-21085            1              1             1           111
# 1    LD-16855            1              1             1           111
# 2    RS-19870            4              1             1           411
# 3    SG-20890            1              1             1           111
# 4    CJ-11875            1              1             1           111

# %%
rfm.shape
# Out:
# (793, 5)

# %% [markdown]
# # Export to csv

# %%
# df.to_csv(r'C:\Users\DavidVicente\Desktop\IronHack\Git_Project_Repos\Project_4_Superstore-Sales-Visualization-\Data\superstore_df.csv')

# %%
rfm.to_csv(r'C:\Users\DavidVicente\Desktop\IronHack\Git_Project_Repos\Project_4_Superstore-Sales-Visualization-\Data\superstore_rfm.csv', index=False)
